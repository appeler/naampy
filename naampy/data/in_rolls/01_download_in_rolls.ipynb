# %%
# Dataverse API Token
# https://dataverse.harvard.edu/dataverseuser.xhtml?selectTab=apiTokenTab
token = "API TOKEN"

# %%
from pyDataverse.api import Api

# %%
api = Api("https://dataverse.harvard.edu/", token)
api.status
# Out:
# 'OK'

# %%
resp = api.get_dataset("doi:10.7910/DVN/MUEGDT")
j = resp.json()
j
# Out:
# {'status': 'OK',
#  'data': {'id': 3108394,
#   'identifier': 'DVN/MUEGDT',
#   'persistentUrl': 'https://doi.org/10.7910/DVN/MUEGDT',
#   'protocol': 'doi',
#   'authority': '10.7910',
#   'publisher': 'Harvard Dataverse',
#   'publicationDate': '2018-03-17',
#   'storageIdentifier': 's3://10.7910/DVN/MUEGDT',
#   'latestVersion': {'id': 259629,
#    'datasetId': 3108394,
#    'datasetPersistentId': 'doi:10.7910/DVN/MUEGDT',
#    'storageIdentifier': 's3://10.7910/DVN/MUEGDT',
#    'versionNumber': 19,
#    'versionMinorNumber': 0,
#    'versionState': 'RELEASED',
#    'UNF': 'UNF:6:gukaSdWqK3KHktrhahO/7w==',
#    'lastUpdateTime': '2021-08-01T04:36:19Z',
#    'releaseTime': '2021-08-01T04:36:19Z',
#    'createTime': '2021-08-01T02:28:06Z',
#    'license': 'CC0',
#    'termsOfUse': 'CC0 Waiver',
#    'termsOfAccess': "We care about people's privacy. The data are only available for research purposes. By requesting the data you agree to not sell the data for commercial gain and to do your best to protect the privacy of people. You can only request this data if you have a university ID. ",
#    'fileAccessRequest': True,
#    'metadataBlocks': {'citation': {'displayName': 'Citation Metadata',
#      'fields': [{'typeName': 'title',
#        'multiple': False,
#        'typeClass': 'primitive',
#        'value': 'Parsed Indian Electoral Rolls'},
#       {'typeName': 'author',
#        'multiple': True,
#        'typeClass': 'compound',
#        'value': [{'authorName': {'typeName': 'authorName',
#           'multiple': False,
#           'typeClass': 'primitive',
#           'value': 'Sood, Gaurav'}},
#         {'authorName': {'typeName': 'authorName',
#           'multiple': False,
#           'typeClass': 'primitive',
#           'value': 'Laohaprapanon, Suriyan'}},
#         {'authorName': {'typeName': 'authorName',
#           'multiple': False,
#           'typeClass': 'primitive',
#           'value': 'Sanjeevi, Madhu'}},
#         {'authorName': {'typeName': 'authorName',
#           'multiple': False,
#           'typeClass': 'primitive',
#           'value': 'Tran, Khanh'}}]},
#       {'typeName': 'datasetContact',
#        'multiple': True,
#        'typeClass': 'compound',
#        'value': [{'datasetContactName': {'typeName': 'datasetContactName',
#           'multiple': False,
#           'typeClass': 'primitive',
#           'value': 'Sood, Gaurav'},
#          'datasetContactEmail': {'typeName': 'datasetContactEmail',
#           'multiple': False,
#           'typeClass': 'primitive',
#           'value': 'gsood07@gmail.com'}}]},
#       {'typeName': 'dsDescription',
#        'multiple': True,
#        'typeClass': 'compound',
#        'value': [{'dsDescriptionValue': {'typeName': 'dsDescriptionValue',
#           'multiple': False,
#           'typeClass': 'primitive',
#           'value': 'For getting the pdfs of electoral rolls, see <a href="https://github.com/in-rolls/electoral_rolls">https://github.com/in-rolls/electoral_rolls</a>.\n\nFor scripts used to parse the electoral rolls, see <a href="https://github.com/in-rolls/parse_elex_rolls">https://github.com/in-rolls/parse_elex_rolls</a> \n\nIf you would like access to the electoral rolls, please fill out the following <a href="https://goo.gl/forms/R7ESMtH9463QH97h1">form</a>.\n\nYou will need to also get IRB approval from your respective university or institution. The IRB-approved proposal should include:\n<ul>\n<li>Case for why the data are necessary\n<li>Acknowledgment that the data will be kept in a secure environment\n<li>All the people who will have access to the data\n<li>That the data will only be used on projects with IRB approval\n<li>That data won\'t be shared with people who are not identified in 3.\n<li>That publications and presentations will not reveal identifying individual information: only statistical summaries will be presented.\n</ul>'}}]},
#       {'typeName': 'subject',
#        'multiple': True,
#        'typeClass': 'controlledVocabulary',
#        'value': ['Social Sciences']},
#       {'typeName': 'depositor',
#        'multiple': False,
#        'typeClass': 'primitive',
#        'value': 'Sood, Gaurav'},
#       {'typeName': 'dateOfDeposit',
#        'multiple': False,
#        'typeClass': 'primitive',
#        'value': '2021-05-18'}]}},
#    'files': [{'label': 'andaman-1.tab',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 3148009,
#       'persistentId': 'doi:10.7910/DVN/MUEGDT/4ZMGTU',
#       'pidURL': 'https://doi.org/10.7910/DVN/MUEGDT/4ZMGTU',
#       'filename': 'andaman-1.tab',
#       'contentType': 'text/tab-separated-values',
#       'filesize': 64410653,
#       'storageIdentifier': 's3://dvn-cloud:16304d35c22-d3ebfd34991c',
#       'originalFileFormat': 'text/csv',
#       'originalFormatLabel': 'Comma Separated Values',
#       'originalFileSize': 58581352,
#       'originalFileName': 'andaman-1.csv',
#       'UNF': 'UNF:6:rxYieFjnrZatOHW5Tr2+NQ==',
#       'rootDataFileId': -1,
#       'md5': 'ac4d64d118a594bae0cba50bcdd1c632',
#       'checksum': {'type': 'MD5', 'value': 'ac4d64d118a594bae0cba50bcdd1c632'},
#       'creationDate': '2018-04-26'}},
#     {'label': 'andhra.7z',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 3149067,
#       'persistentId': 'doi:10.7910/DVN/MUEGDT/OD04TA',
#       'pidURL': 'https://doi.org/10.7910/DVN/MUEGDT/OD04TA',
#       'filename': 'andhra.7z',
#       'contentType': 'application/x-7z-compressed',
#       'filesize': 504529800,
#       'storageIdentifier': 's3://dvn-cloud:16322a9401a-10e8b30268df',
#       'rootDataFileId': -1,
#       'md5': '893d24f36657e9d13488e5c321d5f5d0',
#       'checksum': {'type': 'MD5', 'value': '893d24f36657e9d13488e5c321d5f5d0'},
#       'creationDate': '2018-05-02'}},
#     {'label': 'arunachal.tab',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 3148007,
#       'persistentId': 'doi:10.7910/DVN/MUEGDT/HKCEEJ',
#       'pidURL': 'https://doi.org/10.7910/DVN/MUEGDT/HKCEEJ',
#       'filename': 'arunachal.tab',
#       'contentType': 'text/tab-separated-values',
#       'filesize': 240416974,
#       'storageIdentifier': 's3://dvn-cloud:16304d3d10d-06def7ca02fa',
#       'originalFileFormat': 'text/csv',
#       'originalFormatLabel': 'Comma Separated Values',
#       'originalFileSize': 220875368,
#       'originalFileName': 'arunachal.csv',
#       'UNF': 'UNF:6:igcJWeFb/ALZ37sKTt+O/Q==',
#       'rootDataFileId': -1,
#       'md5': '50927ad977c9f467ccb3a17fc8fa3f01',
#       'checksum': {'type': 'MD5', 'value': '50927ad977c9f467ccb3a17fc8fa3f01'},
#       'creationDate': '2018-04-26'}},
#     {'description': '',
#      'label': 'assam_all_clean+t13n.csv.gz',
#      'restricted': True,
#      'version': 2,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4940365,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'assam_all_clean+t13n.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 303949076,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17aff8e5ae5-b79660b80b72',
#       'rootDataFileId': -1,
#       'md5': 'adf53c2118bc4215dc7fd64427fa396b',
#       'checksum': {'type': 'MD5', 'value': 'adf53c2118bc4215dc7fd64427fa396b'},
#       'creationDate': '2021-07-31'}},
#     {'description': '',
#      'label': 'assam_all.csv.gz',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4570131,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'assam_all.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 208555551,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:178ec7db307-67017b0b0dd6',
#       'rootDataFileId': -1,
#       'md5': '1317b7e55893ffdab00f41ac4cf34250',
#       'checksum': {'type': 'MD5', 'value': '1317b7e55893ffdab00f41ac4cf34250'},
#       'creationDate': '2021-04-19'}},
#     {'description': '',
#      'label': 'bihar_all_clean+t13n.csv.gz.partaa',
#      'restricted': True,
#      'version': 2,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4940359,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'bihar_all_clean+t13n.csv.gz.partaa',
#       'contentType': 'application/gzip',
#       'filesize': 2147483648,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17aff8b74d0-340af4a75898',
#       'rootDataFileId': -1,
#       'md5': 'dabcb64ccb0873a37df1acf05c8133e9',
#       'checksum': {'type': 'MD5', 'value': 'dabcb64ccb0873a37df1acf05c8133e9'},
#       'creationDate': '2021-07-31'}},
#     {'description': '',
#      'label': 'bihar_all_clean+t13n.csv.gz.partab',
#      'restricted': True,
#      'version': 2,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4940356,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'bihar_all_clean+t13n.csv.gz.partab',
#       'contentType': 'application/octet-stream',
#       'filesize': 701965505,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17aff8a788f-ef3699dd69e8',
#       'rootDataFileId': -1,
#       'md5': '8cfb5b3e6bb91381db0af4b108f82fb5',
#       'checksum': {'type': 'MD5', 'value': '8cfb5b3e6bb91381db0af4b108f82fb5'},
#       'creationDate': '2021-07-31'}},
#     {'description': '',
#      'label': 'bihar_all.csv.gz',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4302092,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'bihar_all.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 1824420412,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17706a8af69-20a344bd0ee9',
#       'rootDataFileId': -1,
#       'md5': '50ac21cf55af83e3bf6ffbfb983410ad',
#       'checksum': {'type': 'MD5', 'value': '50ac21cf55af83e3bf6ffbfb983410ad'},
#       'creationDate': '2021-01-15'}},
#     {'description': '',
#      'label': 'chandigarh_all_clean+t13n.csv.gz',
#      'restricted': True,
#      'version': 2,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4940375,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'chandigarh_all_clean+t13n.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 23165519,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17aff913690-8b71af798549',
#       'rootDataFileId': -1,
#       'md5': '43165e9bf7dfc0f78e7cd12569557e2a',
#       'checksum': {'type': 'MD5', 'value': '43165e9bf7dfc0f78e7cd12569557e2a'},
#       'creationDate': '2021-07-31'}},
#     {'description': '',
#      'label': 'chandigarh_all.csv.gz',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4579210,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'chandigarh_all.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 15215459,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:178f9e2c976-dc0a14235c32',
#       'rootDataFileId': -1,
#       'md5': 'f14903c1d2566cdf05b25835f6bbb02f',
#       'checksum': {'type': 'MD5', 'value': 'f14903c1d2566cdf05b25835f6bbb02f'},
#       'creationDate': '2021-04-22'}},
#     {'description': '',
#      'label': 'chandigarh.csv.gz',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4275489,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'chandigarh.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 14563003,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:1769c4adca8-6008d27a84a3',
#       'rootDataFileId': -1,
#       'md5': 'b1ce3319c43faf2e8e1133adb849f670',
#       'checksum': {'type': 'MD5', 'value': 'b1ce3319c43faf2e8e1133adb849f670'},
#       'creationDate': '2020-12-25'}},
#     {'label': 'dadra.tab',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 3148008,
#       'persistentId': 'doi:10.7910/DVN/MUEGDT/3PCEYO',
#       'pidURL': 'https://doi.org/10.7910/DVN/MUEGDT/3PCEYO',
#       'filename': 'dadra.tab',
#       'contentType': 'text/tab-separated-values',
#       'filesize': 34140336,
#       'storageIdentifier': 's3://dvn-cloud:16304d3e31b-edc5a8291e39',
#       'originalFileFormat': 'text/csv',
#       'originalFormatLabel': 'Comma Separated Values',
#       'originalFileSize': 30437784,
#       'originalFileName': 'dadra.csv',
#       'UNF': 'UNF:6:MHFX9EsUONs8SajiDbD2Zw==',
#       'rootDataFileId': -1,
#       'md5': 'ecd82dcfb5b5a31673575fda322100e0',
#       'checksum': {'type': 'MD5', 'value': 'ecd82dcfb5b5a31673575fda322100e0'},
#       'creationDate': '2018-04-26'}},
#     {'label': 'daman-1.tab',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 3148006,
#       'persistentId': 'doi:10.7910/DVN/MUEGDT/OSUUAJ',
#       'pidURL': 'https://doi.org/10.7910/DVN/MUEGDT/OSUUAJ',
#       'filename': 'daman-1.tab',
#       'contentType': 'text/tab-separated-values',
#       'filesize': 32772556,
#       'storageIdentifier': 's3://dvn-cloud:16304d42ab6-131a2421992b',
#       'originalFileFormat': 'text/csv',
#       'originalFormatLabel': 'Comma Separated Values',
#       'originalFileSize': 29861386,
#       'originalFileName': 'daman-1.csv',
#       'UNF': 'UNF:6:6/tm8x2fcNw+28hj7eIxUQ==',
#       'rootDataFileId': -1,
#       'md5': '6cd508c8c4a9b10ea8ac729b311f6482',
#       'checksum': {'type': 'MD5', 'value': '6cd508c8c4a9b10ea8ac729b311f6482'},
#       'creationDate': '2018-04-26'}},
#     {'description': '',
#      'label': 'delhi_eng_all_clean.csv.gz',
#      'restricted': True,
#      'version': 2,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4940373,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'delhi_eng_all_clean.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 222017872,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17aff91098a-60ef4cac8ec9',
#       'rootDataFileId': -1,
#       'md5': '313c9385e8d388c1fd391c43d020507e',
#       'checksum': {'type': 'MD5', 'value': '313c9385e8d388c1fd391c43d020507e'},
#       'creationDate': '2021-07-31'}},
#     {'description': '',
#      'label': 'delhi_eng_all.csv.gz',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4809359,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'delhi_eng_all.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 227641134,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17a23322bbc-7fe15777fdfc',
#       'rootDataFileId': -1,
#       'md5': '5512a3cf72bf413f082eb453919d1ab4',
#       'checksum': {'type': 'MD5', 'value': '5512a3cf72bf413f082eb453919d1ab4'},
#       'creationDate': '2021-06-19'}},
#     {'label': 'goa.tab',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 3148382,
#       'persistentId': 'doi:10.7910/DVN/MUEGDT/EOSYCP',
#       'pidURL': 'https://doi.org/10.7910/DVN/MUEGDT/EOSYCP',
#       'filename': 'goa.tab',
#       'contentType': 'text/tab-separated-values',
#       'filesize': 334365325,
#       'storageIdentifier': 's3://dvn-cloud:16312f84cf8-87205d3ac3bc',
#       'originalFileFormat': 'text/csv',
#       'originalFormatLabel': 'Comma Separated Values',
#       'originalFileSize': 304924618,
#       'originalFileName': 'goa.csv',
#       'UNF': 'UNF:6:F+NQ88NhD5b0A/h5LpONIg==',
#       'rootDataFileId': -1,
#       'md5': '1f9f2e0c19f8dcd2e057b9a8d9cf27dc',
#       'checksum': {'type': 'MD5', 'value': '1f9f2e0c19f8dcd2e057b9a8d9cf27dc'},
#       'creationDate': '2018-04-29'}},
#     {'description': '',
#      'label': 'guj_all_clean+t13n.csv.gz',
#      'restricted': True,
#      'version': 2,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4940367,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'guj_all_clean+t13n.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 864668053,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17aff8ec93b-17d0f740b913',
#       'rootDataFileId': -1,
#       'md5': '2076b32de82a3410c910a058cdc00a63',
#       'checksum': {'type': 'MD5', 'value': '2076b32de82a3410c910a058cdc00a63'},
#       'creationDate': '2021-07-31'}},
#     {'description': '',
#      'label': 'guj_all.csv.gz',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4754389,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'guj_all.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 559890549,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:179b54a8c8c-7c8e21e2af86',
#       'rootDataFileId': -1,
#       'md5': '10523dba6b766dca0d64cf33c51cf567',
#       'checksum': {'type': 'MD5', 'value': '10523dba6b766dca0d64cf33c51cf567'},
#       'creationDate': '2021-05-28'}},
#     {'description': '',
#      'label': 'har_all_clean+t13n.csv.gz',
#      'restricted': True,
#      'version': 2,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4940357,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'har_all_clean+t13n.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 573899486,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17aff8ac6b9-5befb113c649',
#       'rootDataFileId': -1,
#       'md5': '0f90ce90455f1e1c5604ca4faf6c9534',
#       'checksum': {'type': 'MD5', 'value': '0f90ce90455f1e1c5604ca4faf6c9534'},
#       'creationDate': '2021-07-31'}},
#     {'description': '',
#      'label': 'har_all.csv.gz',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4777602,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'har_all.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 385440286,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:179d7d547f3-07e5c5363d8e',
#       'rootDataFileId': -1,
#       'md5': '1ae870bf532679841b4270db1b2fe051',
#       'checksum': {'type': 'MD5', 'value': '1ae870bf532679841b4270db1b2fe051'},
#       'creationDate': '2021-06-04'}},
#     {'description': '',
#      'label': 'haryana.csv.gz',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4275490,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'haryana.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 367724457,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:1769c4b0230-ccf84f62d30a',
#       'rootDataFileId': -1,
#       'md5': '3e4f53061b65a55178d83d39f496213c',
#       'checksum': {'type': 'MD5', 'value': '3e4f53061b65a55178d83d39f496213c'},
#       'creationDate': '2020-12-25'}},
#     {'description': '',
#      'label': 'himachal_all_clean+t13n.csv.gz',
#      'restricted': True,
#      'version': 2,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4940362,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'himachal_all_clean+t13n.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 169962859,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17aff8d2548-6829dc6f997c',
#       'rootDataFileId': -1,
#       'md5': '561157b9c6379558cbfcf2a68115950e',
#       'checksum': {'type': 'MD5', 'value': '561157b9c6379558cbfcf2a68115950e'},
#       'creationDate': '2021-07-31'}},
#     {'description': '',
#      'label': 'himachal_all.csv.gz',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4579175,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'himachal_all.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 114709772,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:178f948c191-ee210d035d39',
#       'rootDataFileId': -1,
#       'md5': 'e56374735e1ce0eb8934acc28c33e944',
#       'checksum': {'type': 'MD5', 'value': 'e56374735e1ce0eb8934acc28c33e944'},
#       'creationDate': '2021-04-22'}},
#     {'description': '',
#      'label': 'himachal.csv.gz',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4275491,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'himachal.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 101099654,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:1769c4b1dfb-3e3c194032a2',
#       'rootDataFileId': -1,
#       'md5': 'a468488d7f2c75acadd17098f642fcb6',
#       'checksum': {'type': 'MD5', 'value': 'a468488d7f2c75acadd17098f642fcb6'},
#       'creationDate': '2020-12-25'}},
#     {'description': '',
#      'label': 'jha_all_clean+t13n.csv.gz',
#      'restricted': True,
#      'version': 2,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4940380,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'jha_all_clean+t13n.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 839437062,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17aff93f75e-2dcb4d5c93e7',
#       'rootDataFileId': -1,
#       'md5': '7788526295f26455b407781846c533dc',
#       'checksum': {'type': 'MD5', 'value': '7788526295f26455b407781846c533dc'},
#       'creationDate': '2021-07-31'}},
#     {'description': '',
#      'label': 'jha_all.csv.gz',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4887470,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'jha_all.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 554806303,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17a998ab718-64d81e581636',
#       'rootDataFileId': -1,
#       'md5': '8a7d0f3dc58c079c901c429ac1e494a2',
#       'checksum': {'type': 'MD5', 'value': '8a7d0f3dc58c079c901c429ac1e494a2'},
#       'creationDate': '2021-07-12'}},
#     {'label': 'jk.tab',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 3148010,
#       'persistentId': 'doi:10.7910/DVN/MUEGDT/WFYB4R',
#       'pidURL': 'https://doi.org/10.7910/DVN/MUEGDT/WFYB4R',
#       'filename': 'jk.tab',
#       'contentType': 'text/tab-separated-values',
#       'filesize': 50015779,
#       'storageIdentifier': 's3://dvn-cloud:16304d4739e-2efab3b2c64f',
#       'originalFileFormat': 'text/csv',
#       'originalFormatLabel': 'Comma Separated Values',
#       'originalFileSize': 45260206,
#       'originalFileName': 'jk.csv',
#       'UNF': 'UNF:6:T2SlHG89reGZBksT41WyvQ==',
#       'rootDataFileId': -1,
#       'md5': '7e1c658033be7e890f5da0eb71519536',
#       'checksum': {'type': 'MD5', 'value': '7e1c658033be7e890f5da0eb71519536'},
#       'creationDate': '2018-04-26'}},
#     {'description': '',
#      'label': 'kar_all_clean+t13n.csv.gz',
#      'restricted': True,
#      'version': 2,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4940360,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'kar_all_clean+t13n.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 293980628,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17aff8c0e60-99c31b95eb66',
#       'rootDataFileId': -1,
#       'md5': 'a6c25f737d4621e73a0cb04848cfb236',
#       'checksum': {'type': 'MD5', 'value': 'a6c25f737d4621e73a0cb04848cfb236'},
#       'creationDate': '2021-07-31'}},
#     {'description': '',
#      'label': 'kar_all.csv.gz',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4785795,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'kar_all.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 198059070,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:179e3af87fc-453f3113cd9e',
#       'rootDataFileId': -1,
#       'md5': '06e0b0ae922bc6b1b6a6f59e6c45e5f0',
#       'checksum': {'type': 'MD5', 'value': '06e0b0ae922bc6b1b6a6f59e6c45e5f0'},
#       'creationDate': '2021-06-06'}},
#     {'description': '',
#      'label': 'kerala_all_clean.csv.gz',
#      'restricted': True,
#      'version': 2,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4940355,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'kerala_all_clean.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 427014722,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17aff8a2da1-7ef54d17aa96',
#       'rootDataFileId': -1,
#       'md5': '8ef04412fe8d41fb21893e9360c8d702',
#       'checksum': {'type': 'MD5', 'value': '8ef04412fe8d41fb21893e9360c8d702'},
#       'creationDate': '2021-07-31'}},
#     {'description': '',
#      'label': 'kerala_all.csv.gz',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4515020,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'kerala_all.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 432124542,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:178c38d2dc7-32e60db48380',
#       'rootDataFileId': -1,
#       'md5': '00423c91c28153be726c6fb4f0939f2f',
#       'checksum': {'type': 'MD5', 'value': '00423c91c28153be726c6fb4f0939f2f'},
#       'creationDate': '2021-04-11'}},
#     {'description': '',
#      'label': 'large',
#      'restricted': True,
#      'version': 2,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4940382,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'large',
#       'contentType': 'application/octet-stream',
#       'filesize': 0,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17aff942182-afeb4c377e7e',
#       'rootDataFileId': -1,
#       'md5': 'd41d8cd98f00b204e9800998ecf8427e',
#       'checksum': {'type': 'MD5', 'value': 'd41d8cd98f00b204e9800998ecf8427e'},
#       'creationDate': '2021-07-31'}},
#     {'description': '',
#      'label': 'maharashtra_all_clean+t13n.csv.gz.partaa',
#      'restricted': True,
#      'version': 2,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4940378,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'maharashtra_all_clean+t13n.csv.gz.partaa',
#       'contentType': 'application/gzip',
#       'filesize': 2147483648,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17aff925b80-4eeba7ee16b3',
#       'rootDataFileId': -1,
#       'md5': '012f404809a07767d15791a68dc46eca',
#       'checksum': {'type': 'MD5', 'value': '012f404809a07767d15791a68dc46eca'},
#       'creationDate': '2021-07-31'}},
#     {'description': '',
#      'label': 'maharashtra_all_clean+t13n.csv.gz.partab',
#      'restricted': True,
#      'version': 2,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4940368,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'maharashtra_all_clean+t13n.csv.gz.partab',
#       'contentType': 'application/octet-stream',
#       'filesize': 1562753710,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17aff8f6566-40d643081183',
#       'rootDataFileId': -1,
#       'md5': '0746e8c026a6e497a8a3a384ea50135c',
#       'checksum': {'type': 'MD5', 'value': '0746e8c026a6e497a8a3a384ea50135c'},
#       'creationDate': '2021-07-31'}},
#     {'description': '',
#      'label': 'maharashtra_all.csv.gz',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4570020,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'maharashtra_all.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 2423617841,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:178ea6d5108-55ea1f03dfae',
#       'rootDataFileId': -1,
#       'md5': 'b16e7f96ba45ef1759e7a0768f840aad',
#       'checksum': {'type': 'MD5', 'value': 'b16e7f96ba45ef1759e7a0768f840aad'},
#       'creationDate': '2021-04-19'}},
#     {'label': 'manipur.tab',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 3148393,
#       'persistentId': 'doi:10.7910/DVN/MUEGDT/YVWSPW',
#       'pidURL': 'https://doi.org/10.7910/DVN/MUEGDT/YVWSPW',
#       'filename': 'manipur.tab',
#       'contentType': 'text/tab-separated-values',
#       'filesize': 516199260,
#       'storageIdentifier': 's3://dvn-cloud:163142699c8-e08ab1552156',
#       'originalFileFormat': 'text/csv',
#       'originalFormatLabel': 'Comma Separated Values',
#       'originalFileSize': 458125766,
#       'originalFileName': 'manipur.csv',
#       'UNF': 'UNF:6:UNal854oqF5Zas2/Bzj72Q==',
#       'rootDataFileId': -1,
#       'md5': '7268ceb7ed449ee2bc89377ba4cdf7b5',
#       'checksum': {'type': 'MD5', 'value': '7268ceb7ed449ee2bc89377ba4cdf7b5'},
#       'creationDate': '2018-04-29'}},
#     {'label': 'meghalaya.tab',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 3148365,
#       'persistentId': 'doi:10.7910/DVN/MUEGDT/R61MBS',
#       'pidURL': 'https://doi.org/10.7910/DVN/MUEGDT/R61MBS',
#       'filename': 'meghalaya.tab',
#       'contentType': 'text/tab-separated-values',
#       'filesize': 485475895,
#       'storageIdentifier': 's3://dvn-cloud:16312632124-51d9ee2d1ebb',
#       'originalFileFormat': 'text/csv',
#       'originalFormatLabel': 'Comma Separated Values',
#       'originalFileSize': 438116162,
#       'originalFileName': 'meghalaya.csv',
#       'UNF': 'UNF:6:Plm0iVAVxyMt7HJ0UQwHrQ==',
#       'rootDataFileId': -1,
#       'md5': 'ec8c39d570e85d8df0f7514f33fde785',
#       'checksum': {'type': 'MD5', 'value': 'ec8c39d570e85d8df0f7514f33fde785'},
#       'creationDate': '2018-04-29'}},
#     {'label': 'mizoram.tab',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 3148392,
#       'persistentId': 'doi:10.7910/DVN/MUEGDT/WDKAMK',
#       'pidURL': 'https://doi.org/10.7910/DVN/MUEGDT/WDKAMK',
#       'filename': 'mizoram.tab',
#       'contentType': 'text/tab-separated-values',
#       'filesize': 213501046,
#       'storageIdentifier': 's3://dvn-cloud:16314271f83-6b9ec47ebf69',
#       'originalFileFormat': 'text/csv',
#       'originalFormatLabel': 'Comma Separated Values',
#       'originalFileSize': 191618060,
#       'originalFileName': 'mizoram.csv',
#       'UNF': 'UNF:6:yXpLH1m8PELz4Bn0gJWb2w==',
#       'rootDataFileId': -1,
#       'md5': '05d4ef303df4e8c9ec7e261657111d97',
#       'checksum': {'type': 'MD5', 'value': '05d4ef303df4e8c9ec7e261657111d97'},
#       'creationDate': '2018-04-29'}},
#     {'description': '',
#      'label': 'mp_all_clean+t13n.csv.gz',
#      'restricted': True,
#      'version': 2,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4940370,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'mp_all_clean+t13n.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 1676050073,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17aff90292a-6cb30c0d9cab',
#       'rootDataFileId': -1,
#       'md5': '6c62de989dd90e1c00090380fb24e6d2',
#       'checksum': {'type': 'MD5', 'value': '6c62de989dd90e1c00090380fb24e6d2'},
#       'creationDate': '2021-07-31'}},
#     {'description': '',
#      'label': 'mp_all.csv.gz',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4754390,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'mp_all.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 1102669868,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:179b54b47d7-46d0c0fb8782',
#       'rootDataFileId': -1,
#       'md5': '524296ecdb5f99d278823824b799521d',
#       'checksum': {'type': 'MD5', 'value': '524296ecdb5f99d278823824b799521d'},
#       'creationDate': '2021-05-28'}},
#     {'label': 'nagaland.tab',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 3148394,
#       'persistentId': 'doi:10.7910/DVN/MUEGDT/PA5PCW',
#       'pidURL': 'https://doi.org/10.7910/DVN/MUEGDT/PA5PCW',
#       'filename': 'nagaland.tab',
#       'contentType': 'text/tab-separated-values',
#       'filesize': 295203821,
#       'storageIdentifier': 's3://dvn-cloud:163143fd331-ac319a9c0b06',
#       'originalFileFormat': 'text/csv',
#       'originalFormatLabel': 'Comma Separated Values',
#       'originalFileSize': 262045318,
#       'originalFileName': 'nagaland.csv',
#       'UNF': 'UNF:6:iTtxLZFzqb8HiOhkTAgNXg==',
#       'rootDataFileId': -1,
#       'md5': 'ad5268ebad2c4cefcb30ffd57bb3da1f',
#       'checksum': {'type': 'MD5', 'value': 'ad5268ebad2c4cefcb30ffd57bb3da1f'},
#       'creationDate': '2018-04-29'}},
#     {'description': '',
#      'label': 'odi_all_clean+t13n.csv.gz',
#      'restricted': True,
#      'version': 2,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4940361,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'odi_all_clean+t13n.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 1495601717,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17aff8cc7ae-43b9a84905bd',
#       'rootDataFileId': -1,
#       'md5': '2591e5d32732c6f16312cd1980137b4f',
#       'checksum': {'type': 'MD5', 'value': '2591e5d32732c6f16312cd1980137b4f'},
#       'creationDate': '2021-07-31'}},
#     {'description': '',
#      'label': 'odi_all.csv.gz',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4793848,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'odi_all.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 972267844,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17a039a4ed8-5f565fbd23dd',
#       'rootDataFileId': -1,
#       'md5': 'cdb5d1a7ffae8eb0327743ea505576d3',
#       'checksum': {'type': 'MD5', 'value': 'cdb5d1a7ffae8eb0327743ea505576d3'},
#       'creationDate': '2021-06-13'}},
#     {'label': 'puducherry.tab',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 3148014,
#       'persistentId': 'doi:10.7910/DVN/MUEGDT/VIU5JH',
#       'pidURL': 'https://doi.org/10.7910/DVN/MUEGDT/VIU5JH',
#       'filename': 'puducherry.tab',
#       'contentType': 'text/tab-separated-values',
#       'filesize': 341981751,
#       'storageIdentifier': 's3://dvn-cloud:16304e707f4-e2a73028a1cb',
#       'originalFileFormat': 'text/csv',
#       'originalFormatLabel': 'Comma Separated Values',
#       'originalFileSize': 316673687,
#       'originalFileName': 'puducherry.csv',
#       'UNF': 'UNF:6:pTPoi63qnj+qie4P2f/htA==',
#       'rootDataFileId': -1,
#       'md5': 'b14c238af2351af23affa7acd0c790a9',
#       'checksum': {'type': 'MD5', 'value': 'b14c238af2351af23affa7acd0c790a9'},
#       'creationDate': '2018-04-26'}},
#     {'description': '',
#      'label': 'punjab_all_clean+t13n.csv.gz',
#      'restricted': True,
#      'version': 2,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4940371,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'punjab_all_clean+t13n.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 691026548,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17aff90a12f-187201e16a4a',
#       'rootDataFileId': -1,
#       'md5': '186f5ceb66560616dacae92142d5a047',
#       'checksum': {'type': 'MD5', 'value': '186f5ceb66560616dacae92142d5a047'},
#       'creationDate': '2021-07-31'}},
#     {'description': '',
#      'label': 'punjab_all.csv.gz',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4579625,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'punjab_all.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 477274331,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:178fcbb7f5d-9707a49705b6',
#       'rootDataFileId': -1,
#       'md5': '574488c239a128ace54e6acf14448b20',
#       'checksum': {'type': 'MD5', 'value': '574488c239a128ace54e6acf14448b20'},
#       'creationDate': '2021-04-22'}},
#     {'description': '',
#      'label': 'rajasthan_all_clean+t13n.csv.gz',
#      'restricted': True,
#      'version': 2,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4940383,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'rajasthan_all_clean+t13n.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 1494471793,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17aff949b02-24599a38066e',
#       'rootDataFileId': -1,
#       'md5': 'de3f7f49bd7092f2f48ae8b6a114e8a6',
#       'checksum': {'type': 'MD5', 'value': 'de3f7f49bd7092f2f48ae8b6a114e8a6'},
#       'creationDate': '2021-07-31'}},
#     {'description': '',
#      'label': 'rajasthan_all.csv.gz',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4656611,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'rajasthan_all.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 1017895457,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:1797fcef672-b9e5059aeb42',
#       'rootDataFileId': -1,
#       'md5': 'c4d200ee659deff8bc5bda0c856886b6',
#       'checksum': {'type': 'MD5', 'value': 'c4d200ee659deff8bc5bda0c856886b6'},
#       'creationDate': '2021-05-18'}},
#     {'description': '',
#      'label': 'sikkim_all_clean.csv.gz',
#      'restricted': True,
#      'version': 2,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4940374,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'sikkim_all_clean.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 7946199,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17aff9122ba-f7e5ea6b054e',
#       'rootDataFileId': -1,
#       'md5': '5def90e0ea82e91c5b21f94d3fa0041e',
#       'checksum': {'type': 'MD5', 'value': '5def90e0ea82e91c5b21f94d3fa0041e'},
#       'creationDate': '2021-07-31'}},
#     {'description': '',
#      'label': 'sikkim_all.csv.gz',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4570378,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'sikkim_all.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 8305617,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:178ed3d0239-4b31a2407d0c',
#       'rootDataFileId': -1,
#       'md5': 'ee524c8b2f919300f1ede083ff4efd8e',
#       'checksum': {'type': 'MD5', 'value': 'ee524c8b2f919300f1ede083ff4efd8e'},
#       'creationDate': '2021-04-19'}},
#     {'description': '',
#      'label': 'tripura_all_clean+t13n.csv.gz',
#      'restricted': True,
#      'version': 2,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4940366,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'tripura_all_clean+t13n.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 92472379,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17aff8e7abd-f241babbc782',
#       'rootDataFileId': -1,
#       'md5': '9c07cdd50c455ad44708b4fecbb602a8',
#       'checksum': {'type': 'MD5', 'value': '9c07cdd50c455ad44708b4fecbb602a8'},
#       'creationDate': '2021-07-31'}},
#     {'description': '',
#      'label': 'tripura_all.csv.gz',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4810243,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'tripura_all.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 61492534,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17a28274dea-7c3053b914cc',
#       'rootDataFileId': -1,
#       'md5': 'cc861db5832fe1ae1186d99bdd95ebc5',
#       'checksum': {'type': 'MD5', 'value': 'cc861db5832fe1ae1186d99bdd95ebc5'},
#       'creationDate': '2021-06-20'}},
#     {'description': '',
#      'label': 'up_all_clean+t13n.csv.gz.partaa',
#      'restricted': True,
#      'version': 2,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4940379,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'up_all_clean+t13n.csv.gz.partaa',
#       'contentType': 'application/gzip',
#       'filesize': 2147483648,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17aff9365d4-2d471daf8248',
#       'rootDataFileId': -1,
#       'md5': 'b9e6d1600686ebaef98fa1561c5670bc',
#       'checksum': {'type': 'MD5', 'value': 'b9e6d1600686ebaef98fa1561c5670bc'},
#       'creationDate': '2021-07-31'}},
#     {'description': '',
#      'label': 'up_all_clean+t13n.csv.gz.partab',
#      'restricted': True,
#      'version': 2,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4940364,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'up_all_clean+t13n.csv.gz.partab',
#       'contentType': 'application/octet-stream',
#       'filesize': 2147483648,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17aff8dec0e-dc318b6e7bab',
#       'rootDataFileId': -1,
#       'md5': '108963ff13cef1ea24b4e304c6a0427b',
#       'checksum': {'type': 'MD5', 'value': '108963ff13cef1ea24b4e304c6a0427b'},
#       'creationDate': '2021-07-31'}},
#     {'description': '',
#      'label': 'up_all_clean+t13n.csv.gz.partac',
#      'restricted': True,
#      'version': 2,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4940376,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'up_all_clean+t13n.csv.gz.partac',
#       'contentType': 'application/octet-stream',
#       'filesize': 809754114,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17aff918584-d045c8e13a60',
#       'rootDataFileId': -1,
#       'md5': 'a970c102388389a5a3ff552fe5386cf8',
#       'checksum': {'type': 'MD5', 'value': 'a970c102388389a5a3ff552fe5386cf8'},
#       'creationDate': '2021-07-31'}},
#     {'description': '',
#      'label': 'up_all.csv.gz.partaa',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4722898,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'up_all.csv.gz.partaa',
#       'contentType': 'application/gzip',
#       'filesize': 2147483648,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17981f18a8a-1779651692c5',
#       'rootDataFileId': -1,
#       'md5': '70088c8386facd4db8b20d6e87565aaf',
#       'checksum': {'type': 'MD5', 'value': '70088c8386facd4db8b20d6e87565aaf'},
#       'creationDate': '2021-05-18'}},
#     {'description': '',
#      'label': 'up_all.csv.gz.partab',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4722899,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'up_all.csv.gz.partab',
#       'contentType': 'application/octet-stream',
#       'filesize': 1369789037,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17981f2bd52-4ab971962887',
#       'rootDataFileId': -1,
#       'md5': '3651ccb6bb707fb6550b462e10efc1b1',
#       'checksum': {'type': 'MD5', 'value': '3651ccb6bb707fb6550b462e10efc1b1'},
#       'creationDate': '2021-05-18'}},
#     {'description': '',
#      'label': 'utt_all_clean+t13n.csv.gz',
#      'restricted': True,
#      'version': 2,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4940372,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'utt_all_clean+t13n.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 244907885,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17aff90ddf0-4237182be597',
#       'rootDataFileId': -1,
#       'md5': '1b61956d071df6cd7954baabef3fc2d1',
#       'checksum': {'type': 'MD5', 'value': '1b61956d071df6cd7954baabef3fc2d1'},
#       'creationDate': '2021-07-31'}},
#     {'description': '',
#      'label': 'utt_all.csv.gz',
#      'restricted': True,
#      'version': 1,
#      'datasetVersionId': 259629,
#      'dataFile': {'id': 4889226,
#       'persistentId': '',
#       'pidURL': '',
#       'filename': 'utt_all.csv.gz',
#       'contentType': 'application/gzip',
#       'filesize': 162017953,
#       'description': '',
#       'storageIdentifier': 's3://dvn-cloud:17aa2a647cf-64e07e703d8a',
#       'rootDataFileId': -1,
#       'md5': '54ce647bd65979fc24ad34ab78e51fd7',
#       'checksum': {'type': 'MD5', 'value': '54ce647bd65979fc24ad34ab78e51fd7'},
#       'creationDate': '2021-07-13'}}]}}}

# %%
files = []
for file in j["data"]["latestVersion"]["files"]:
    fid = file["dataFile"]["id"]
    fn = file["dataFile"]["filename"]
    print(fid, fn)
    if fn.endswith(".tab") or fn.endswith(".7z"):
        files.append((fid, fn))
# Out:
# 3148009 andaman-1.tab
# 3149067 andhra.7z
# 3148007 arunachal.tab
# 4940365 assam_all_clean+t13n.csv.gz
# 4570131 assam_all.csv.gz
# 4940359 bihar_all_clean+t13n.csv.gz.partaa
# 4940356 bihar_all_clean+t13n.csv.gz.partab
# 4302092 bihar_all.csv.gz
# 4940375 chandigarh_all_clean+t13n.csv.gz
# 4579210 chandigarh_all.csv.gz
# 4275489 chandigarh.csv.gz
# 3148008 dadra.tab
# 3148006 daman-1.tab
# 4940373 delhi_eng_all_clean.csv.gz
# 4809359 delhi_eng_all.csv.gz
# 3148382 goa.tab
# 4940367 guj_all_clean+t13n.csv.gz
# 4754389 guj_all.csv.gz
# 4940357 har_all_clean+t13n.csv.gz
# 4777602 har_all.csv.gz
# 4275490 haryana.csv.gz
# 4940362 himachal_all_clean+t13n.csv.gz
# 4579175 himachal_all.csv.gz
# 4275491 himachal.csv.gz
# 4940380 jha_all_clean+t13n.csv.gz
# 4887470 jha_all.csv.gz
# 3148010 jk.tab
# 4940360 kar_all_clean+t13n.csv.gz
# 4785795 kar_all.csv.gz
# 4940355 kerala_all_clean.csv.gz
# 4515020 kerala_all.csv.gz
# 4940382 large
# 4940378 maharashtra_all_clean+t13n.csv.gz.partaa
# 4940368 maharashtra_all_clean+t13n.csv.gz.partab
# 4570020 maharashtra_all.csv.gz
# 3148393 manipur.tab
# 3148365 meghalaya.tab
# 3148392 mizoram.tab
# 4940370 mp_all_clean+t13n.csv.gz
# 4754390 mp_all.csv.gz
# 3148394 nagaland.tab
# 4940361 odi_all_clean+t13n.csv.gz
# 4793848 odi_all.csv.gz
# 3148014 puducherry.tab
# 4940371 punjab_all_clean+t13n.csv.gz
# 4579625 punjab_all.csv.gz
# 4940383 rajasthan_all_clean+t13n.csv.gz
# 4656611 rajasthan_all.csv.gz
# 4940374 sikkim_all_clean.csv.gz
# 4570378 sikkim_all.csv.gz
# 4940366 tripura_all_clean+t13n.csv.gz
# 4810243 tripura_all.csv.gz
# 4940379 up_all_clean+t13n.csv.gz.partaa
# 4940364 up_all_clean+t13n.csv.gz.partab
# 4940376 up_all_clean+t13n.csv.gz.partac
# 4722898 up_all.csv.gz.partaa
# 4722899 up_all.csv.gz.partab
# 4940372 utt_all_clean+t13n.csv.gz
# 4889226 utt_all.csv.gz

# %%
files
# Out:
# [(3148009, 'andaman-1.tab'),
#  (3149067, 'andhra.7z'),
#  (3148007, 'arunachal.tab'),
#  (3148008, 'dadra.tab'),
#  (3148006, 'daman-1.tab'),
#  (3148382, 'goa.tab'),
#  (3148010, 'jk.tab'),
#  (3148393, 'manipur.tab'),
#  (3148365, 'meghalaya.tab'),
#  (3148392, 'mizoram.tab'),
#  (3148394, 'nagaland.tab'),
#  (3148014, 'puducherry.tab')]

# %%
import requests


def download_file(url, fn):
    local_filename = fn  # url.split('/')[-1]
    # NOTE the stream=True parameter below
    with requests.get(url, stream=True) as r:
        r.raise_for_status()
        with open(local_filename, "wb") as f:
            for chunk in r.iter_content(chunk_size=8192):
                if chunk:  # filter out keep-alive new chunks
                    f.write(chunk)
                    # f.flush()
    return local_filename

# %%
for fid, fn in files:
    print(fn)
    url = "https://dataverse.harvard.edu//api/v1/access/datafile/%s?key=%s" % (
        fid,
        token,
    )
    download_file(url, fn)
# Out:
# andaman-1.tab
# andhra.7z
# arunachal.tab
# dadra.tab
# daman-1.tab
# goa.tab
# jk.tab
# manipur.tab
# meghalaya.tab
# mizoram.tab
# nagaland.tab
# puducherry.tab

# %% [markdown]
# ### V2: Assume other new 19 states data already exists on the local storage
